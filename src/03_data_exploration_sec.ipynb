# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import gcsfs
import json

# %% [markdown]
# ## Loading files

# %%
# function to load quarterly data from Google Cloud Storage

def load_4q_year_gcs(base_path: str, year: int):
    fs = gcsfs.GCSFileSystem()

    df_num = {}
    df_sub = {}
    df_tag = {}

    for q in [1, 2, 3, 4]:
        qname = f"q{q}"

        num_path = f"{base_path}/{year}q{q}/num.parquet"
        sub_path = f"{base_path}/{year}q{q}/sub.parquet"
        tag_path = f"{base_path}/{year}q{q}/tag.parquet"

        df_num[qname] = pd.read_parquet(num_path, filesystem=fs) if fs.exists(num_path) else None
        df_sub[qname] = pd.read_parquet(sub_path, filesystem=fs) if fs.exists(sub_path) else None
        df_tag[qname] = pd.read_parquet(tag_path, filesystem=fs) if fs.exists(tag_path) else None

    return df_num, df_sub, df_tag

# %%
BASE = "gs://sec-financials-edgar/sec_edgar_financials/parquet"

df_num, df_sub, df_tag = load_4q_year_gcs(BASE, 2010)

df_num_q1 = df_num["q1"]
df_num_q2 = df_num["q2"]
df_num_q3 = df_num["q3"]
df_num_q4 = df_num["q4"]

df_sub_q1 = df_sub["q1"]
df_sub_q2 = df_sub["q2"]
df_sub_q3 = df_sub["q3"]
df_sub_q4 = df_sub["q4"]

df_tag_q1 = df_tag["q1"]
df_tag_q2 = df_tag["q2"]
df_tag_q3 = df_tag["q3"]
df_tag_q4 = df_tag["q4"]

# %% [markdown]
# ## Concat Files and Filter Files

# %%
# concatenate quarterly dataframes sub data
df_sub_all = pd.concat(
    [df_sub_q1, df_sub_q2, df_sub_q3, df_sub_q4],
    ignore_index=True
)

df_sub_all = df_sub_all.drop_duplicates(subset=["adsh"])

# %%
df_sub_all.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3903 entries, 0 to 3902
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        3903 non-null   str
#  1   cik         3903 non-null   int64
#  2   name        3903 non-null   str
#  3   sic         3903 non-null   int64
#  4   countryba   3902 non-null   str
#  5   stprba      3697 non-null   str
#  6   cityba      3903 non-null   str
#  7   zipba       3871 non-null   str
#  8   bas1        3878 non-null   str
#  9   bas2        1395 non-null   str
#  10  baph        3857 non-null   str
#  11  countryma   3735 non-null   str
#  12  stprma      3558 non-null   str
#  13  cityma      3737 non-null   str
#  14  zipma       3732 non-null   str
#  15  mas1        3737 non-null   str
#  16  mas2        1278 non-null   str
#  17  countryinc  3603 non-null   str
#  18  stprinc     3481 non-null   str
#  19  ein         3903 non-null   int64
#  20  former      1900 non-null   str
#  21  changed     1900 non-null   float64
#  22  afs         3901 non-null   str
#  23  wksi        3903 non-null   int64
#  24  fye         3903 non-null   int64
#  25  form        3903 non-null   str
#  26  period      3903 non-null   int64
#  27  fy          3895 non-null   float64
#  28  fp          3895 non-null   str
#  29  filed       3903 non-null   int64
#  30  accepted    3903 non-null   str
#  31  prevrpt     3903 non-null   int64
#  32  detail      3903 non-null   int64
#  33  instance    3903 non-null   str
#  34  nciks       3903 non-null   int64
#  35  aciks       158 non-null    str
# dtypes: float64(2), int64(10), str(24)
# memory usage: 1.8 MB

# %%
df_sub_all["adsh"].nunique()
# Out:
# 3903

# %%
sub_cols = [
'adsh',
 'cik',
 'name',
 'sic',
 'form',
 'period',
 'fy',
 'fp',
 'filed',
 'prevrpt',
]

df_sub = df_sub_all[sub_cols]

# %%
# concatenate quarterly dataframes tag data
df_tag_all = pd.concat(
    [df_tag_q1, df_tag_q2, df_tag_q3, df_tag_q4],
    ignore_index=True
)

df_tag_all = df_tag_all.drop_duplicates(subset=["tag", "version"])

# %%
df_tag_all.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 50166 entries, 0 to 56969
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tag       50166 non-null  str
#  1   version   50166 non-null  str
#  2   custom    50166 non-null  int64
#  3   abstract  50166 non-null  int64
#  4   datatype  50166 non-null  str
#  5   iord      50166 non-null  str
#  6   crdr      44024 non-null  str
#  7   tlabel    50159 non-null  str
#  8   doc       48899 non-null  str
# dtypes: int64(2), str(7)
# memory usage: 17.9 MB

# %%
# Check if this combo is fully unique
df_tag_all.duplicated(subset=["tag", "version"]).sum()
# Out:
# np.int64(0)

# %%
tag_cols = [
    "tag",
    "version",
    "custom",
    "abstract",
    "datatype",
    "iord",
]

df_tag = df_tag_all[tag_cols]

# %%
# concatenate quarterly dataframes num data
df_num_all = pd.concat(
    [df_num_q1, df_num_q2, df_num_q3, df_num_q4],
    ignore_index=True
)

df_num_all = df_num_all.drop_duplicates(
    subset=["adsh", "tag", "version", "ddate", "qtrs", "uom", "segments", "coreg"]
)

# %%
df_num_all.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1322905 entries, 0 to 1322904
# Data columns (total 10 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   adsh      1322905 non-null  str
#  1   tag       1322905 non-null  str
#  2   version   1322905 non-null  str
#  3   ddate     1322905 non-null  int64
#  4   qtrs      1322905 non-null  int64
#  5   uom       1322905 non-null  str
#  6   segments  351244 non-null   str
#  7   coreg     96474 non-null    str
#  8   value     1311459 non-null  float64
#  9   footnote  2478 non-null     str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 210.5 MB

# %%
df_num_all.duplicated(subset=["adsh", "tag", "version", "ddate", "qtrs", "uom", "segments", "coreg"]).sum()
# Out:
# np.int64(0)

# %%
num_cols = [
    'adsh',
    'tag',
    'version',
    'uom',
    'qtrs',
    'ddate',
    'value',
    'segments',
    'coreg'
]
df_num = df_num_all[num_cols]

# %%
df_num_tag = df_num.merge(
    df_tag,
    on=["tag", "version"],
    how="left",
    validate="many_to_one"
)

# %%
# TAG must be unique
assert not df_tag_all.duplicated(["tag", "version"]).any()

# NUM should not lose rows after merge
print("NUM rows:", len(df_num_all))
# Out:
# NUM rows: 1322905

# %%
assert len(df_num_tag) == len(df_num_all)

# %%
df_num_tag["datatype"].isna().mean() * 100
# Out:
# np.float64(0.0)

# %%
# SUB must be unique on adsh
assert not df_sub_all.duplicated(["adsh"]).any()

print("NUM+TAG rows:", len(df_num_tag))
print("SUB rows:", len(df_sub_all))
# Out:
# NUM+TAG rows: 1322905
# SUB rows: 3903

# %%
df_fact = df_num_tag.merge(
    df_sub,
    on="adsh",
    how="left",
    validate="many_to_one"
)

# %%
assert len(df_fact) == len(df_num_tag)

# %%
df_fact["cik"].isna().mean() * 100
# Out:
# np.float64(0.0)

# %%
# Ensure numeric types
df_fact["cik"] = df_fact["cik"].astype("int64")

df_fact["fy"] = pd.to_numeric(df_fact["fy"], errors="coerce")
df_fact["period"] = pd.to_numeric(df_fact["period"], errors="coerce")

# Standardize form
df_fact["form"] = df_fact["form"].str.strip()

# %%
# Standardize strings
df_fact["tag"] = df_fact["tag"].str.strip()
df_fact["version"] = df_fact["version"].str.strip()

# Ensure numeric value is float
df_fact["value"] = pd.to_numeric(df_fact["value"], errors="coerce")

# %%
df_fact.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1322905 entries, 0 to 1322904
# Data columns (total 22 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   adsh      1322905 non-null  str
#  1   tag       1322905 non-null  str
#  2   version   1322905 non-null  str
#  3   uom       1322905 non-null  str
#  4   qtrs      1322905 non-null  int64
#  5   ddate     1322905 non-null  int64
#  6   value     1311459 non-null  float64
#  7   segments  351244 non-null   str
#  8   coreg     96474 non-null    str
#  9   custom    1322905 non-null  int64
#  10  abstract  1322905 non-null  int64
#  11  datatype  1322905 non-null  str
#  12  iord      1322905 non-null  str
#  13  cik       1322905 non-null  int64
#  14  name      1322905 non-null  str
#  15  sic       1322905 non-null  int64
#  16  form      1322905 non-null  str
#  17  period    1322905 non-null  int64
#  18  fy        1319833 non-null  float64
#  19  fp        1319833 non-null  str
#  20  filed     1322905 non-null  int64
#  21  prevrpt   1322905 non-null  int64
# dtypes: float64(2), int64(9), str(11)
# memory usage: 375.6 MB

# %%
df_fact["form"].value_counts()
# Out:
# form
# 10-Q      955328
# 10-K      232617
# 10-Q/A     56102
# 8-K        25784
# 20-F       13263
# 6-K        12155
# 20-F/A      9897
# 10-K/A      7449
# S-4         3957
# 6-K/A       2995
# S-4/A       1743
# 8-K/A        618
# POS AM       435
# 40-F         295
# 40-F/A       267
# Name: count, dtype: int64

# %%
# Filter the df_fact to only include 10-K and 10-KA
df_fact = df_fact[df_fact["form"].isin(["10-K", "10-K/A"])]

# %%
df_fact["form"].value_counts()
# Out:
# form
# 10-K      232617
# 10-K/A      7449
# Name: count, dtype: int64

# %%
df_fact.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 240066 entries, 0 to 1322879
# Data columns (total 22 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   adsh      240066 non-null  str
#  1   tag       240066 non-null  str
#  2   version   240066 non-null  str
#  3   uom       240066 non-null  str
#  4   qtrs      240066 non-null  int64
#  5   ddate     240066 non-null  int64
#  6   value     239103 non-null  float64
#  7   segments  72626 non-null   str
#  8   coreg     9058 non-null    str
#  9   custom    240066 non-null  int64
#  10  abstract  240066 non-null  int64
#  11  datatype  240066 non-null  str
#  12  iord      240066 non-null  str
#  13  cik       240066 non-null  int64
#  14  name      240066 non-null  str
#  15  sic       240066 non-null  int64
#  16  form      240066 non-null  str
#  17  period    240066 non-null  int64
#  18  fy        237206 non-null  float64
#  19  fp        237206 non-null  str
#  20  filed     240066 non-null  int64
#  21  prevrpt   240066 non-null  int64
# dtypes: float64(2), int64(9), str(11)
# memory usage: 70.5 MB

# %%
df_fact["cik"].nunique()
# Out:
# 542

# %%
df_fact["fy"].value_counts().sort_index()
# Out:
# fy
# 2009.0    174180
# 2010.0     63026
# Name: count, dtype: int64

# %%
# Convert fy to integer type
df_fact["fy"] = (
    df_fact["fy"]
    .round(0)               
    .astype("Int64")        
)

# %%
# filter to keep only 10-K and 10-K/A filings
df_fact = df_fact[df_fact["form"].isin(["10-K", "10-K/A"])]

# %%
# count of unique companies in fy 2010
count_2009 = df_fact[df_fact["fy"] == 2009]["cik"].nunique()
count_2010 = df_fact[df_fact["fy"] == 2010]["cik"].nunique()

print(f"Unique companies in FY 2009: {count_2009} and FY 2010: {count_2010}")
# Out:
# Unique companies in FY 2009: 402 and FY 2010: 137

# %%
# 1) store unique fy in a list
fy_list = sorted(df_fact["fy"].dropna().unique())

df_names = []

# 2-4) use the list to store dataframes separately + name them based on the list
split_dfs = {}

for fy in fy_list:
    df_name = f"df_fact_{fy}"
    split_dfs[df_name] = df_fact[df_fact["fy"] == fy].copy()
    globals()[df_name] = split_dfs[df_name]  # creates df_fact_2009, df_fact_2010, etc.
    df_names.append(df_name)

# optional check
print("Fiscal years found:", fy_list)
print("Created dataframes:", list(split_dfs.keys()))
# Out:
# Fiscal years found: [np.int64(2009), np.int64(2010)]
# Created dataframes: ['df_fact_2009', 'df_fact_2010']

# %%
# plot the distribution of number of facts per filing for both dataframes in the df_names list
for year in df_names:
    df_current = globals()[year]
    facts_per_filing = df_current.groupby("adsh").size()
    plt.figure(figsize=(10, 6))
    sns.histplot(facts_per_filing, bins=50, kde=False)
    plt.title(f"Distribution of Number of Facts per 10-K and 10-K/A Filing (FY {year.split('_')[-1]})")
    plt.xlabel("Number of Facts")
    plt.ylabel("Number of Filings")
    plt.show()

# %%
# plot distribution of unique tags in 10-K and 10-K/A filings for each fiscal year
for year in df_names:
    df_current = globals()[year]
    unique_tags_per_filing = df_current.groupby("adsh")["tag"].nunique()
    plt.figure(figsize=(10, 6))
    sns.histplot(unique_tags_per_filing, bins=50, kde=False)
    plt.title(f"Distribution of Unique Tags per 10-K and 10-K/A Filing (FY {year.split('_')[-1]})")
    plt.xlabel("Number of Unique Tags")
    plt.ylabel("Number of Filings")
    plt.show()

# %%
# unique CIK values in 10-K and 10-K/A filings
for year in df_names:
    df_current = globals()[year]
    cik_counts = df_current[["cik","tag"]].nunique()
    print(f"FY {year.split('_')[-1]} - Unique CIKs: {cik_counts['cik']}, Unique Tags: {cik_counts['tag']}")
# Out:
# FY 2009 - Unique CIKs: 402, Unique Tags: 7710
# FY 2010 - Unique CIKs: 137, Unique Tags: 2660

# %%
# tags that are most commonly used across companies in 10-K and 10-K/A filings for each fiscal year
for year in df_names:
    df_current = globals()[year]
    tag_company_counts_non_null = (
        df_current[df_current["value"].notna()]
        .groupby("tag")["cik"]
        .nunique()
        .sort_values(ascending=False)
    )
    print(f"FY {year.split('_')[-1]} - Top 10 Tags by Company Count:")
    print(tag_company_counts_non_null.head(10))
    print("\n")
# Out:
# FY 2009 - Top 10 Tags by Company Count:
# tag
# Assets                                             400
# LiabilitiesAndStockholdersEquity                   395
# CashAndCashEquivalentsPeriodIncreaseDecrease       395
# IncomeTaxExpenseBenefit                            384
# RetainedEarningsAccumulatedDeficit                 382
# CashAndCashEquivalentsAtCarryingValue              379
# NetCashProvidedByUsedInInvestingActivities         375
# NetCashProvidedByUsedInOperatingActivities         372
# NetCashProvidedByUsedInFinancingActivities         371
# AccumulatedOtherComprehensiveIncomeLossNetOfTax    370
# Name: cik, dtype: int64
#
#
# FY 2010 - Top 10 Tags by Company Count:
# tag
# CashAndCashEquivalentsAtCarryingValue              137
# Assets                                             137
# CashAndCashEquivalentsPeriodIncreaseDecrease       136
# LiabilitiesAndStockholdersEquity                   135
# IncomeTaxExpenseBenefit                            134
# PropertyPlantAndEquipmentNet                       133
# RetainedEarningsAccumulatedDeficit                 132
# EarningsPerShareBasic                              132
# EarningsPerShareDiluted                            131
# AccumulatedOtherComprehensiveIncomeLossNetOfTax    131
# Name: cik, dtype: int64

# %%
# def apply_amendments_by_year(df_names):
#     """
#     Creates NEW amended dataframes with suffix '_amd'
#     Example: df_fact_2009 -> df_fact_2009_amd
#     """

#     amended_names = []

#     for df_name in df_names:
#         df = globals()[df_name].copy()

#         # keep only relevant forms
#         df_forms = df[df["form"].isin(["10-K", "10-K/A"])].copy()

#         # find companies that filed BOTH
#         both_keys = (
#             df_forms.groupby(["cik", "fy"])["form"]
#             .nunique()
#             .reset_index()
#         )

#         both_keys = both_keys[both_keys["form"] == 2][["cik", "fy"]]

#         if both_keys.empty:
#             globals()[f"{df_name}_amd"] = df
#             amended_names.append(f"{df_name}_amd")
#             continue

#         df_both = df_forms.merge(both_keys, on=["cik", "fy"], how="inner")

#         df_10k = df_both[df_both["form"] == "10-K"].copy()
#         df_10ka = df_both[df_both["form"] == "10-K/A"].copy()

#         # merge on tag level
#         merged = df_10k.merge(
#             df_10ka[["cik", "fy", "tag", "value"]]
#                 .rename(columns={"value": "value_10ka"}),
#             on=["cik", "fy", "tag"],
#             how="left"
#         )

#         # replacement logic
#         merged["value_final"] = merged["value_10ka"].combine_first(merged["value"])

#         # update only 10-K rows in original dataframe
#         df_10k_updated = merged[df_10k.columns].copy()
#         df_10k_updated["value"] = merged["value_final"]

#         # remove old 10-K rows
#         df_remaining = df[~(
#             (df["form"] == "10-K") &
#             df.set_index(["cik","fy","tag"]).index.isin(
#                 df_10k.set_index(["cik","fy","tag"]).index
#             )
#         )]

#         # append updated rows
#         df_amended = pd.concat([df_remaining, df_10k_updated], ignore_index=True)

#         # create new dataframe name
#         new_name = f"{df_name}_amd"
#         globals()[new_name] = df_amended
#         amended_names.append(new_name)

#     print("Created amended dataframes:", amended_names)
#     return amended_names


# # APPLY
# amended_df_names = apply_amendments_by_year(df_names)
# Out:
# Created amended dataframes: ['df_fact_2009_amd', 'df_fact_2010_amd']

# %%
def apply_amendments_by_year(df_names, log_path="amended_ciks_log.json"):
    """
    Creates NEW amended dataframes with suffix '_amd' (e.g., df_fact_2009_amd),
    and logs amended CIKs per year-df into a JSON file.

    JSON structure:
    {
      "df_fact_2009": {
        "fy_values": [2009],
        "amended_ciks": [...],
        "n_amended_ciks": 7
      },
      ...
    }
    """
    amended_names = []
    log_obj = {}

    for df_name in df_names:
        df = globals()[df_name].copy()

        # keep only relevant forms
        df_forms = df[df["form"].isin(["10-K", "10-K/A"])].copy()

        # companies (cik, fy) that filed BOTH
        both_keys = (
            df_forms.groupby(["cik", "fy"])["form"]
            .nunique()
            .reset_index(name="n_forms")
        )
        both_keys = both_keys[both_keys["n_forms"] == 2][["cik", "fy"]]

        amended_ciks = sorted(both_keys["cik"].dropna().unique().tolist())
        fy_values = sorted(df_forms["fy"].dropna().unique().tolist())

        log_obj[df_name] = {
            "fy_values": fy_values,
            "amended_ciks": amended_ciks,
            "n_amended_ciks": len(amended_ciks),
        }

        if both_keys.empty:
            new_name = f"{df_name}_amd"
            globals()[new_name] = df
            amended_names.append(new_name)
            continue

        df_both = df_forms.merge(both_keys, on=["cik", "fy"], how="inner")

        df_10k = df_both[df_both["form"] == "10-K"].copy()
        df_10ka = df_both[df_both["form"] == "10-K/A"].copy()

        # merge at tag level within (cik, fy)
        merged = df_10k.merge(
            df_10ka[["cik", "fy", "tag", "value"]].rename(columns={"value": "value_10ka"}),
            on=["cik", "fy", "tag"],
            how="left"
        )

        # replacement rule:
        # - if 10-K/A value exists and differs -> replace
        # - if 10-K/A is null -> keep 10-K value
        merged["value_final"] = merged["value_10ka"].combine_first(merged["value"])

        df_10k_updated = merged[df_10k.columns].copy()
        df_10k_updated["value"] = merged["value_final"]

        # remove original 10-K rows for amended (cik,fy,tag) and replace with updated
        amended_keys_idx = df_10k.set_index(["cik", "fy", "tag"]).index
        keep_mask = ~(
            (df["form"] == "10-K") &
            df.set_index(["cik", "fy", "tag"]).index.isin(amended_keys_idx)
        )
        df_remaining = df[keep_mask].copy()

        df_amended = pd.concat([df_remaining, df_10k_updated], ignore_index=True)

        new_name = f"{df_name}_amd"
        globals()[new_name] = df_amended
        amended_names.append(new_name)

    # write JSON log
    with open(log_path, "w", encoding="utf-8") as f:
        json.dump(log_obj, f, indent=2)

    print("Created amended dataframes:", amended_names)
    print("Wrote amended CIK log to:", log_path)

    return amended_names, log_obj


# APPLY
amended_df_names, amended_log = apply_amendments_by_year(df_names, log_path="amended_ciks_log.json")
# Out:
# Created amended dataframes: ['df_fact_2009_amd', 'df_fact_2010_amd']
# Wrote amended CIK log to: amended_ciks_log.json

# %%
print(f"Number of 10-K filings in FY 2009: {df_10k_2009['adsh'].nunique()}")
print(f"Number of 10-K/A filings in FY 2009: {df_10ka_2009['adsh'].nunique()}")
# Out:
# Number of 10-K filings in FY 2009: 395
# Number of 10-K/A filings in FY 2009: 15

# %%
# tag with non null value appearing in most number of company filings
tag_company_counts_non_null = (
    df_10k_2009[df_10k_2009["value"].notna()]
    .groupby("tag")["cik"]
    .nunique()
    .sort_values(ascending=False)
)

# %%
tag_company_counts_non_null.head(40)
# Out:
# tag
# Assets                                                                                                         451
# LiabilitiesAndStockholdersEquity                                                                               446
# CashAndCashEquivalentsPeriodIncreaseDecrease                                                                   445
# IncomeTaxExpenseBenefit                                                                                        433
# CashAndCashEquivalentsAtCarryingValue                                                                          428
# NetCashProvidedByUsedInInvestingActivities                                                                     424
# RetainedEarningsAccumulatedDeficit                                                                             424
# NetCashProvidedByUsedInFinancingActivities                                                                     420
# NetCashProvidedByUsedInOperatingActivities                                                                     420
# EarningsPerShareBasic                                                                                          416
# AccumulatedOtherComprehensiveIncomeLossNetOfTax                                                                416
# EarningsPerShareDiluted                                                                                        412
# PropertyPlantAndEquipmentNet                                                                                   410
# CommonStockValue                                                                                               405
# NetIncomeLoss                                                                                                  400
# StockholdersEquity                                                                                             382
# CommonStockSharesAuthorized                                                                                    380
# AssetsCurrent                                                                                                  378
# LiabilitiesCurrent                                                                                             376
# CommonStockSharesIssued                                                                                        361
# OtherAssetsNoncurrent                                                                                          359
# CommonStockParOrStatedValuePerShare                                                                            354
# Goodwill                                                                                                       342
# OtherLiabilitiesNoncurrent                                                                                     335
# PaymentsForRepurchaseOfCommonStock                                                                             328
# OperatingIncomeLoss                                                                                            326
# StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest                                         319
# DeferredIncomeTaxExpenseBenefit                                                                                310
# InterestExpense                                                                                                304
# TreasuryStockValue                                                                                             303
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments    300
# PaymentsToAcquirePropertyPlantAndEquipment                                                                     300
# ProfitLoss                                                                                                     297
# ShareBasedCompensation                                                                                         288
# Liabilities                                                                                                    277
# AccountsPayableCurrent                                                                                         277
# WeightedAverageNumberOfSharesOutstandingBasic                                                                  274
# EffectOfExchangeRateOnCashAndCashEquivalents                                                                   273
# WeightedAverageNumberOfDilutedSharesOutstanding                                                                272
# PaymentsForProceedsFromOtherInvestingActivities                                                                266
# Name: cik, dtype: int64

# %%
# plot tag_company_counts_non_null
plt.figure(figsize=(12, 8))
sns.barplot(
    x=tag_company_counts_non_null.head(20).values,
    y=tag_company_counts_non_null.head(20).index,
    palette="viridis"
)
plt.title("Top 20 Tags by Number of Companies with Non-Null Values (FY 2009)")
plt.xlabel("Number of Companies")
plt.ylabel("Tag")
plt.show()
# Out:
# /var/folders/jd/v519p2hx2z39h95x5gtvw8mm0000gn/T/ipykernel_59360/4124161185.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
tag_company_counts.head(40)
# Out:
# tag
# Assets                                                                                                         539
# CashAndCashEquivalentsPeriodIncreaseDecrease                                                                   533
# LiabilitiesAndStockholdersEquity                                                                               532
# IncomeTaxExpenseBenefit                                                                                        521
# CashAndCashEquivalentsAtCarryingValue                                                                          517
# RetainedEarningsAccumulatedDeficit                                                                             515
# NetCashProvidedByUsedInInvestingActivities                                                                     508
# NetCashProvidedByUsedInOperatingActivities                                                                     505
# EarningsPerShareBasic                                                                                          504
# NetCashProvidedByUsedInFinancingActivities                                                                     504
# AccumulatedOtherComprehensiveIncomeLossNetOfTax                                                                503
# EarningsPerShareDiluted                                                                                        501
# PropertyPlantAndEquipmentNet                                                                                   497
# CommonStockValue                                                                                               479
# NetIncomeLoss                                                                                                  477
# AssetsCurrent                                                                                                  466
# LiabilitiesCurrent                                                                                             464
# CommonStockSharesAuthorized                                                                                    456
# StockholdersEquity                                                                                             454
# OtherAssetsNoncurrent                                                                                          444
# CommonStockParOrStatedValuePerShare                                                                            443
# CommonStockSharesIssued                                                                                        433
# Goodwill                                                                                                       424
# OtherLiabilitiesNoncurrent                                                                                     416
# OperatingIncomeLoss                                                                                            402
# PaymentsForRepurchaseOfCommonStock                                                                             401
# ShareBasedCompensation                                                                                         381
# DeferredIncomeTaxExpenseBenefit                                                                                378
# PaymentsToAcquirePropertyPlantAndEquipment                                                                     375
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments    373
# WeightedAverageNumberOfSharesOutstandingBasic                                                                  363
# AccountsPayableCurrent                                                                                         362
# WeightedAverageNumberOfDilutedSharesOutstanding                                                                362
# InterestExpense                                                                                                361
# StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest                                         351
# TreasuryStockValue                                                                                             343
# InventoryNet                                                                                                   329
# Liabilities                                                                                                    329
# EffectOfExchangeRateOnCashAndCashEquivalents                                                                   327
# IncreaseDecreaseInInventories                                                                                  324
# Name: cik, dtype: int64

# %%
n_companies = df_fact_10k_cleaned["cik"].nunique()

keep_tags = tag_company_counts[
    tag_company_counts >= 0.70 * n_companies
].index

# %%
cum_share = tag_counts.cumsum() / tag_counts.sum()
top_tags = cum_share[cum_share <= 0.90].index  # keep 90% coverage

df_filtered = df_fact_10k_cleaned[df_fact_10k_cleaned["tag"].isin(top_tags)]

# %%
print(f"length of keep_tags: {len(keep_tags)} and tags are {keep_tags}")

# %%
df_filtered["tag"].nunique()

# %%
df_filtered.info()

# %%
df_pre[df_pre["adsh"] == "0000004904-10-000018"]

# %%
df_pre["tag"].value_counts()

# %%
# plot a box plot for the tag value counts
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_pre["tag"].value_counts())
plt.title("Box Plot of Tag Value Counts")
plt.xlabel("Value Counts")
plt.show()

# %%
# count common tags per adsh and plot a box plot
tag_counts_per_adsh = df_pre.groupby('adsh')['tag'].nunique()
tag_counts_per_adsh.head()
plt.figure(figsize=(12, 6))
sns.boxplot(x=tag_counts_per_adsh)
plt.title("Box Plot of Unique Tag Counts per ADSH")
plt.xlabel("Unique Tag Counts")
plt.show()

# %%
# most repeated unique tags across all filings
df_pre['tag'].value_counts().head(20)

# %%
dup_ct = df_pre_small.duplicated(subset=["adsh", "tag","line", "version","plabel"]).sum()
dup_ct

# %%
pre_key = ["adsh", "tag","line", "version"]

# %%
dups = df_pre[df_pre.duplicated(subset=pre_key, keep=False)] \
    .sort_values(pre_key)

dups.info()

# %%
df_pre.info()

# %%
df_sub.info()

# %%
df_sub["form"].value_counts()

# %%
df_sub["cik"].value_counts()

# %%
df_sub[["cik","form"]].value_counts()

# %%
sub = df_sub.copy()

# %%
forms = {"10-K", "10-K/A", "10-Q"}

sub = sub[sub["form"].isin(forms)]

# %%
sub.info()

# %%
sub["form"].value_counts()

# %%
sub["filed_year"] = pd.to_datetime(sub["filed"]).dt.year

# %%
sub = sub.sort_values(["cik", "filed_year", "filed"])

# %%
latest = (
    sub
    .groupby(["cik", "filed_year"], as_index=False)
    .tail(1)
)

# %%
latest["form"].value_counts()

# %%
count_10k_latest = (latest["form"] == "10-K").sum()
count_10q_latest = (latest["form"] == "10-Q").sum()

# %%
count_10k_latest

# %%
count_10q_latest

# %%
count_10ka_latest = (latest["form"] == "10-K/A").sum()
count_10ka_latest

# %%
def has_forms(group):
    forms = set(group["form"])
    return {
        "has_10k": "10-K" in forms,
        "has_10q": "10-Q" in forms,
        "has_10ka": "10-K/A" in forms,
        "latest_form": group.iloc[-1]["form"]
    }

summary = (
    sub
    .groupby(["cik", "filed_year"])
    .apply(has_forms)
    .apply(pd.Series)
    .reset_index()
)

# %%
# 10-K/A is latest AND both 10-K and 10-Q exist
count_10ka_after_both = (
    (summary["latest_form"] == "10-K/A") &
    (summary["has_10k"]) &
    (summary["has_10q"])
).sum()

# %%
count_10ka_after_both

# %% [markdown]
# ## Exploring SUB

# %%
df_sub1 = pd.read_parquet("gs://sec-financials-edgar/sec_edgar_financials/parquet/2010q1/sub.parquet")

# %%
df_sub2 = pd.read_parquet("gs://sec-financials-edgar/sec_edgar_financials/parquet/2010q2/sub.parquet")

# %%
df_sub3 = pd.read_parquet("gs://sec-financials-edgar/sec_edgar_financials/parquet/2010q3/sub.parquet")

# %%
df_sub4 = pd.read_parquet("gs://sec-financials-edgar/sec_edgar_financials/parquet/2010q4/sub.parquet")

# %%
df_sub5 = pd.read_parquet("gs://sec-financials-edgar/sec_edgar_financials/parquet/2011q1/sub.parquet")

# %%
df_sub_all = pd.concat(
    [df_sub1, df_sub2, df_sub3, df_sub4],
    axis=0,
    ignore_index=True
)

# %%
df_sub_all.info()

# %%
df_sub_all["cik"].value_counts()

# %%
# filter 314808
df_sub_all_filtered = df_sub_all[df_sub_all["cik"] == 314808]

# %%
display(df_sub_all_filtered[["adsh", "cik", "form", "filed", "fy", "fp","period"]])

# %%
df_sub_all["countryba"].value_counts()

# %%
# filter 314808
df_sub_all_us = df_sub_all[df_sub_all["countryba"] == "US"]

# %%
df_sub_all_us["form"].value_counts()

# %%
df_sub_all_us["cik"].nunique()

# %%
(
    df_sub_all_us
    .groupby(["fy", "form"])
    .size()
    .sort_index()
)

# %%
df_sub_all_us["fp"].value_counts()

# %%
df_annual = df_sub_all_us[df_sub_all_us["fp"] == "FY"]

# %%
df_annual["cik"].nunique()

# %%
df_annual["form"].value_counts()

# %%
df_sub_all_us[df_sub_all_us["fy"] == 2010]["cik"].nunique()

# %%
df_sub_all["cik"].nunique()

# %%
df_sub_all["filed"].value_counts()

# %%
df_sub5_filtered = df_sub5[df_sub5["cik"] == 314808]
df_sub5_filtered[["adsh", "cik", "form", "filed", "fy", "fp","period"]]
